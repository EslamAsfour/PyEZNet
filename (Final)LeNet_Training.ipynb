# %% [markdown]
# <a href="https://colab.research.google.com/github/EslamAsfour/Custom_DL_Framework-Project/blob/main/(Final)LeNet_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1) Clone Github Repo

# %%
# !git clone https://EslamAsfour:@github.com/EslamAsfour/Custom_DL_Framework-Project.git
# Out:
# Cloning into 'Custom_DL_Framework-Project'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 359 (delta 19), reused 24 (delta 8), pack-reused 313
# Receiving objects: 100% (359/359), 833.12 KiB | 14.12 MiB/s, done.
# Resolving deltas: 100% (201/201), done.

# %% [markdown]
# ## 1.1) Create Directory to auto save weights in it

# %%
cd Custom_DL_Framework-Project/
# Out:
# /content/Custom_DL_Framework-Project

# %%
mkdir Logs/

# %% [markdown]
# # 2) Training

# %% [markdown]
# ## 2.1) Import Needed Modules

# %%
import numpy as np
from modules.Layer import *
from modules.LOSS_FUNC import Cross_Entropy_Loss
from modules.Activation_Function import Relu,Softmax
from modules.Net import Net
from modules.PreProcessing_data import GetData

# %% [markdown]
# ## 2.2) Load Dataset

# %%
X_train,y_train,X_test, y_test = GetData()
# Out:
# Loadind data......
# Downloading train-images-idx3-ubyte.gz
# - Download progress: 100%
# Download finished.
# Downloading train-labels-idx1-ubyte.gz
# - Download progress: 100%
# Download finished.
# Downloading t10k-images-idx3-ubyte.gz
# - Download progress: 100%
# Download finished.
# Downloading t10k-labels-idx1-ubyte.gz
# - Download progress: 100%
# Download finished.
# Preparing data......

# %% [markdown]
# ## 2.3) Create LeNet Object with the needed Arch

# %%
LeNet = Net(layers=[
                    Conv2D(in_Channels= 1,out_Channels = 6, Kernal_Size= 5, Padding=2  ,Stride= 1),
                    Relu(), 
                    MaxPool2D(kernel_size=2), 
                    Conv2D(in_Channels= 6,out_Channels = 16, Kernal_Size= 5, Padding=0  ,Stride= 1),
                    Relu(),
                    MaxPool2D(kernel_size=2),
                    Conv2D(in_Channels= 16,out_Channels = 120, Kernal_Size= 5, Padding=0  ,Stride= 1),
                    Relu(),
                    Flatten(),
                    FullyConnectedLayer(input_dim= 120,output_dim=84),
                    Relu(),
                    FullyConnectedLayer(input_dim=84,output_dim=10),
                    ], loss=Cross_Entropy_Loss())

# %% [markdown]
# ## 2.4) Start Training Loop with parameter Tuning

# %%
n_epoch = 10
batch_size = 32
batch_num = 0
total_Num_Patch = int(X_train.shape[0]/batch_size)

for e in range(n_epoch):
    batch_num = 0
    for batch_index in range(0, X_train.shape[0], batch_size):
        batch_num +=1
        if batch_index + batch_size < X_train.shape[0]:
            end_Index =   batch_index+batch_size
            x = X_train[ batch_index : end_Index ]
            y = y_train[ batch_index : end_Index ]
            
        else :
            end_Index =   X_train.shape[0]
            x = X_train[batch_index : end_Index]
            y = y_train[batch_index: end_Index]
        
        # Forward Prop
        out = LeNet(x)
        # Calc Accuracy
        
        preds = np.argmax(out, axis=1).reshape(-1, 1)
        accuracy_per_Patch = ( preds == y ).sum() / batch_size
        accuracy_per_Patch = accuracy_per_Patch*100
        # Calc Loss
        loss = LeNet.loss(out, y)
        
        
        # Backward Prop
        LeNet.backward()
        LeNet.weights_update(alpha=1e-3)
        
        print("Epoch no. %d , Patch no. %d/%d , loss =  %2f4 \t accuracy per patch = %d %%" % ( e + 1, batch_num, total_Num_Patch  ,loss, accuracy_per_Patch ))
        
        #Every 100 Batches Save the weights
        if batch_num % 100 == 0 :
            LeNet.save_weights(e+1,batch_num)
# Out:
# Epoch no. 1 , Patch no. 1/1875 , loss =  2.5116604 	 accuracy per patch = 3 %
# Epoch no. 1 , Patch no. 2/1875 , loss =  2.5843584 	 accuracy per patch = 18 %
# Epoch no. 1 , Patch no. 3/1875 , loss =  2.7229274 	 accuracy per patch = 9 %
# Epoch no. 1 , Patch no. 4/1875 , loss =  2.6069324 	 accuracy per patch = 15 %
# Epoch no. 1 , Patch no. 5/1875 , loss =  2.2846574 	 accuracy per patch = 15 %
# Epoch no. 1 , Patch no. 6/1875 , loss =  2.4132654 	 accuracy per patch = 12 %
# Epoch no. 1 , Patch no. 7/1875 , loss =  2.4975254 	 accuracy per patch = 9 %
# Epoch no. 1 , Patch no. 8/1875 , loss =  2.3313234 	 accuracy per patch = 15 %
# Epoch no. 1 , Patch no. 9/1875 , loss =  2.3910294 	 accuracy per patch = 12 %
# Epoch no. 1 , Patch no. 10/1875 , loss =  2.3695504 	 accuracy per patch = 12 %
# Epoch no. 1 , Patch no. 11/1875 , loss =  2.4854204 	 accuracy per patch = 9 %
# Epoch no. 1 , Patch no. 12/1875 , loss =  2.4509254 	 accuracy per patch = 9 %
# Epoch no. 1 , Patch no. 13/1875 , loss =  2.1773294 	 accuracy per patch = 18 %
# Epoch no. 1 , Patch no. 14/1875 , loss =  2.4746094 	 accuracy per patch = 12 %
# Epoch no. 1 , Patch no. 15/1875 , loss =  2.4701294 	 accuracy per patch = 18 %
# Epoch no. 1 , Patch no. 16/1875 , loss =  2.2434434 	 accuracy per patch = 12 %
# Epoch no. 1 , Patch no. 17/1875 , loss =  2.3282494 	 accuracy per patch = 12 %
# Epoch no. 1 , Patch no. 18/1875 , loss =  2.3069354 	 accuracy per patch = 12 %
# Epoch no. 1 , Patch no. 19/1875 , loss =  2.2824384 	 accuracy per patch = 15 %
# Epoch no. 1 , Patch no. 20/1875 , loss =  2.2564964 	 accuracy per patch = 6 %
# Epoch no. 1 , Patch no. 21/1875 , loss =  2.4224284 	 accuracy per patch = 9 %
# Epoch no. 1 , Patch no. 22/1875 , loss =  2.2330774 	 accuracy per patch = 18 %
# Epoch no. 1 , Patch no. 23/1875 , loss =  2.3040114 	 accuracy per patch = 18 %
# Epoch no. 1 , Patch no. 24/1875 , loss =  2.2186024 	 accuracy per patch = 21 %
# Epoch no. 1 , Patch no. 25/1875 , loss =  2.1972924 	 accuracy per patch = 21 %
# Epoch no. 1 , Patch no. 26/1875 , loss =  2.3937124 	 accuracy per patch = 12 %
# Epoch no. 1 , Patch no. 27/1875 , loss =  2.1741234 	 accuracy per patch = 9 %
# Epoch no. 1 , Patch no. 28/1875 , loss =  2.1905454 	 accuracy per patch = 12 %
# Epoch no. 1 , Patch no. 29/1875 , loss =  2.1907184 	 accuracy per patch = 18 %
# Epoch no. 1 , Patch no. 30/1875 , loss =  2.3912224 	 accuracy per patch = 3 %
# Epoch no. 1 , Patch no. 31/1875 , loss =  2.2258604 	 accuracy per patch = 9 %
# Epoch no. 1 , Patch no. 32/1875 , loss =  2.2609004 	 accuracy per patch = 25 %
# Epoch no. 1 , Patch no. 33/1875 , loss =  2.2775404 	 accuracy per patch = 9 %
# Epoch no. 1 , Patch no. 34/1875 , loss =  2.0845724 	 accuracy per patch = 31 %
# Epoch no. 1 , Patch no. 35/1875 , loss =  2.2496774 	 accuracy per patch = 6 %
# Epoch no. 1 , Patch no. 36/1875 , loss =  2.2085484 	 accuracy per patch = 18 %
# Epoch no. 1 , Patch no. 37/1875 , loss =  2.1454154 	 accuracy per patch = 12 %
# Epoch no. 1 , Patch no. 38/1875 , loss =  2.1276694 	 accuracy per patch = 25 %
# Epoch no. 1 , Patch no. 39/1875 , loss =  2.0503734 	 accuracy per patch = 31 %
# Epoch no. 1 , Patch no. 40/1875 , loss =  2.1161444 	 accuracy per patch = 21 %
# Epoch no. 1 , Patch no. 41/1875 , loss =  2.1442804 	 accuracy per patch = 18 %
# Epoch no. 1 , Patch no. 42/1875 , loss =  2.2014664 	 accuracy per patch = 15 %
# Epoch no. 1 , Patch no. 43/1875 , loss =  2.1022534 	 accuracy per patch = 18 %
# Epoch no. 1 , Patch no. 44/1875 , loss =  2.2064984 	 accuracy per patch = 18 %
# Epoch no. 1 , Patch no. 45/1875 , loss =  2.2014134 	 accuracy per patch = 18 %
# Epoch no. 1 , Patch no. 46/1875 , loss =  2.1032274 	 accuracy per patch = 25 %
# Epoch no. 1 , Patch no. 47/1875 , loss =  2.1424914 	 accuracy per patch = 12 %
# Epoch no. 1 , Patch no. 48/1875 , loss =  2.2812734 	 accuracy per patch = 18 %
# Epoch no. 1 , Patch no. 49/1875 , loss =  2.2814744 	 accuracy per patch = 15 %
# Epoch no. 1 , Patch no. 50/1875 , loss =  2.2687494 	 accuracy per patch = 15 %
# Epoch no. 1 , Patch no. 51/1875 , loss =  2.2026794 	 accuracy per patch = 28 %
# Epoch no. 1 , Patch no. 52/1875 , loss =  2.1525644 	 accuracy per patch = 28 %
# Epoch no. 1 , Patch no. 53/1875 , loss =  2.0095344 	 accuracy per patch = 40 %
# Epoch no. 1 , Patch no. 54/1875 , loss =  2.0237394 	 accuracy per patch = 28 %
# Epoch no. 1 , Patch no. 55/1875 , loss =  2.1538404 	 accuracy per patch = 31 %
# Epoch no. 1 , Patch no. 56/1875 , loss =  2.1017254 	 accuracy per patch = 31 %
# Epoch no. 1 , Patch no. 57/1875 , loss =  2.0397874 	 accuracy per patch = 31 %
# Epoch no. 1 , Patch no. 58/1875 , loss =  2.0421504 	 accuracy per patch = 31 %
# Epoch no. 1 , Patch no. 59/1875 , loss =  2.0680014 	 accuracy per patch = 25 %
# Epoch no. 1 , Patch no. 60/1875 , loss =  2.0546624 	 accuracy per patch = 31 %
# Epoch no. 1 , Patch no. 61/1875 , loss =  1.9010434 	 accuracy per patch = 46 %
# Epoch no. 1 , Patch no. 62/1875 , loss =  2.0653724 	 accuracy per patch = 28 %
# Epoch no. 1 , Patch no. 63/1875 , loss =  2.0026694 	 accuracy per patch = 37 %
# Epoch no. 1 , Patch no.
	 accuracy per patch = 93 %
# Epoch no. 3 , Patch no. 306/1875 , loss =  0.5691654 	 accuracy per patch = 87 %
# Epoch no. 3 , Patch no. 307/1875 , loss =  0.2219404 	 accuracy per patch = 93 %
# Epoch no. 3 , Patch no. 308/1875 , loss =  0.0378594 	 accuracy per patch = 100 %
# Epoch no. 3 , Patch no. 309/1875 , loss =  0.3041944 	 accuracy per patch = 84 %
# Epoch no. 3 , Patch no. 310/1875 , loss =  0.0456344 	 accuracy per patch = 100 %
# Epoch no. 3 , Patch no. 311/1875 , loss =  0.2748684 	 accuracy per patch = 90 %
# Epoch no. 3 , Patch no. 312/1875 , loss =  0.2499524 	 accuracy per patch = 96 %
# Epoch no. 3 , Patch no. 313/1875 , loss =  0.2046904 	 accuracy per patch = 93 %
# Epoch no. 3 , Patch no. 314/1875 , loss =  0.4620864 	 accuracy per patch = 87 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-6605a7c95d50> in <module>()
#      19
#      20         # Forward Prop
# ---> 21         out = LeNet(x)
#      22         # Calc Accuracy
#      23
#
# /content/Custom_DL_Framework-Project/modules/Net.py in __call__(self, *args, **kwargs)
#      27         :return: self.forward
#      28         '''
# ---> 29         return self.forward(*args, **kwargs)
#      30
#      31     def forward(self,x):
#
# /content/Custom_DL_Framework-Project/modules/Net.py in forward(self, x)
#      36
#      37         for layer in self.layers:
# ---> 38             x= layer(x)
#      39         return x
#      40
#
# /content/Custom_DL_Framework-Project/modules/Diff_Func.py in __call__(self, *arg, **kargs)
#      12     def __call__(self, *arg,**kargs):
#      13         # Calc Forward path
# ---> 14         output = self.forward(*arg,**kargs)
#      15         #Calc grads
#      16         self.grad = self.calc_Grad(*arg,**kargs)
#
# /content/Custom_DL_Framework-Project/modules/Layer.py in forward(self, X)
#     204                     Sub_X = X[n , : , H_offset: (H_offset + Filter_H) , W_offset: (W_offset + Filter_W)  ]
#     205
# --> 206                     Y[n , C_out , h , w ] = np.sum(self.weights['W'][C_out] * Sub_X) + self.weights['b'][C_out]
#     207         return Y
#     208     def backward(self , dY):
#
# KeyboardInterrupt:

# %% [markdown]
# # 3) Testing and Evaluation

# %% [markdown]
# ## 3.1) Import Needed Libraries

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3.2) Load Weights

# %%
path = "Logs/Weights_(2)_(1800).pkl"
LeNet.load_weights(path)

# %% [markdown]
# ## 3.3) Testing Randomly

# %%
Training_data,Training_labels,Testing_data , Testing_labels = GetData()

while (1):
    No_ofImage =input("Image Number ")
    if (not No_ofImage.isdigit()):
        break
    No_ofImage = int(No_ofImage)
    Testing_image=Testing_data[No_ofImage]
    Testing_image =Testing_image.reshape((1,1,28,28))
    Image_labels=Testing_labels[No_ofImage]

    #Forwarding path
    out = LeNet(Testing_image)

    #prediction of our Lenet model
    preds = np.argmax(out, axis=1).reshape(-1, 1)

    #output our model prediction
    print("LeNet Prediction is {}".format(preds[0][0]))

    #showing image
    Testing_image=Testing_image.reshape(28,28)
    plt.imshow(Testing_image,cmap='gray')
    plt.show()
# Out:
# Loadind data......
# Preparing data......
# Image Number 5
# LeNet Prediction is 1
# Image Number 6
# LeNet Prediction is 4
# Image Number 100
# LeNet Prediction is 6
# Image Number 500
# LeNet Prediction is 3
# Image Number 199
# LeNet Prediction is 2
# Image Number 1000
# LeNet Prediction is 3
# Image Number 800
# LeNet Prediction is 8
# Image Number 890
# LeNet Prediction is 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     565         """
# --> 566         parts = [self.recv(flags, copy=copy, track=track)]
#     567         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-fa04298e92a4> in <module>()
#       3
#       4 while (1):
# ----> 5     No_ofImage =input("Image Number ")
#       6     if (not No_ofImage.isdigit()):
#       7         break
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %% [markdown]
# ## 3.4) Evaluation

# %%
Training_data,Training_labels,Testing_data , Testing_labels = GetData()

Classes_number = 10
Predictions = []

for image,label in zip (Testing_data ,Testing_labels):

    image =image.reshape((1,1,28,28))
    out = LeNet(image)  #output of forward path

    preds = np.argmax(out, axis=1).reshape(-1, 1) #prediction of our Lenet mode
    Predictions.append(preds[0][0])



def evaluation(No_of_classes,True_Label,Predicted_Label):
    
    confussion_matrix = np.zeros((No_of_classes,No_of_classes))
    True_Label=(True_Label.T)[0] 
    for TL,PL in zip(True_Label,Predicted_Label):
        confussion_matrix[TL][PL]=confussion_matrix[TL][PL]+1

    TP = np.zeros(No_of_classes)
    TN = np.zeros(No_of_classes)
    FP = np.zeros(No_of_classes)
    FN = np.zeros(No_of_classes)
    for i in range(No_of_classes):
        TP[i] = confussion_matrix[i][i]
    Matrix_sum = np.sum(confussion_matrix)
    raw_sum = np.sum(confussion_matrix, axis = 1) 
    column_sum = np.sum(confussion_matrix,axis = 0)
    for i in range(No_of_classes):
        TN[i]= Matrix_sum-(raw_sum[i]+column_sum[i])+confussion_matrix[i][i]
    for i in range(No_of_classes):
        FP[i]= column_sum[i]-confussion_matrix[i][i]
    for i in range(No_of_classes):
        FN[i]=raw_sum[i]-confussion_matrix[i][i]

    accurecy =  np.sum(TP)/Matrix_sum
    accurecy=round(accurecy,2)
    Precision = np.zeros(No_of_classes)

    for i in range(No_of_classes):
        Precision[i]=TP[i]/(TP[i]+FN[i])
        Precision[i]=round(Precision[i],2)
    Recall = np.zeros(No_of_classes)

    for i in range(No_of_classes):
        Recall[i] = TP[i]/(TP[i]+TN[i])
        Recall[i]=round(Recall[i],2)
    print("TP:",TP)
    print("TN:",TN)
    print("FP:",FP)
    print("FN",FN)
    print("acc:",accurecy)
    print("Per:",Precision)
    print("Rec:",Recall)
    precision_Avg = round(np.sum(Precision)/No_of_classes,2)
    Recall_Avg = round(np.sum(Recall)/No_of_classes,2)

    print("Avg precision",precision_Avg)
    print("Avg ReCall",Recall_Avg)



evaluation(Classes_number,Testing_labels,Predictions)
# Out:
# Loadind data......
# Preparing data......
# TP: [ 963. 1103.  954.  945.  879.  792.  894.  958.  855.  844.]
# TN: [8963. 8844. 8871. 8867. 8966. 9039. 8979. 8845. 8886. 8927.]
# FP: [ 57.  21.  97. 123.  52.  69.  63. 127. 140.  64.]
# FN [ 17.  32.  78.  65. 103. 100.  64.  70. 119. 165.]
# acc: 0.92
# Per: [0.98 0.97 0.92 0.94 0.9  0.89 0.93 0.93 0.88 0.84]
# Rec: [0.1  0.11 0.1  0.1  0.09 0.08 0.09 0.1  0.09 0.09]
# Avg precision 0.92
# Avg ReCall 0.1
